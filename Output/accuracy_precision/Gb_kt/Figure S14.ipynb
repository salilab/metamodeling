# %%
import pandas as pd
import matplotlib.pyplot as plt
import matplotlib.ticker 
import matplotlib as mpl
import numpy as np
import scipy.stats
font = {'family' : 'Arial narrow',
        'size'   : 20}
COLOR = '#202020'
mpl.rc('font', **font)
mpl.rc('xtick', labelsize=20) 
mpl.rc('ytick', labelsize=20) 
mpl.rcParams['text.color'] = COLOR
mpl.rcParams['axes.labelcolor'] = COLOR
mpl.rcParams['xtick.color'] = COLOR
mpl.rcParams['ytick.color'] = COLOR

# %%
df_scan_cov=pd.read_csv('metamodel_scan_input_kt_cov_output_Gb_with_kt_mean_as_evidence.csv''')
display(df_scan_cov)
# Out:
#      INPUT_kt_mu  INPUT_kt_cov  Gb.postprandial_mu  Gb.postprandial_sigma2  \
# 0             10         0.001            5.067798                0.091148
# 1             10         0.004            5.063552                0.091153
# 2             10         0.009            5.070823                0.091160
# 3             10         0.016            5.069580                0.091170
# 4             10         0.025            5.070026                0.091184
# ..           ...           ...                 ...                     ...
# 96            10         9.224            5.070972                0.101599
# 97            10         9.415            5.070976                0.101786
# 98            10         9.608            5.070975                0.101976
# 99            10         9.803            5.070982                0.102166
# 100           10        10.000            5.070987                0.102358
#
#      Gb.postprandial_sigma  G.postprandial_mu  G.postprandial_sigma2  \
# 0                 0.301907           5.100557               0.020318
# 1                 0.301915           5.099113               0.020319
# 2                 0.301927           5.102187               0.020321
# 3                 0.301944           5.101206               0.020323
# 4                 0.301966           5.100877               0.020326
# ..                     ...                ...                    ...
# 96                0.318746           5.101211               0.022589
# 97                0.319040           5.101092               0.022628
# 98                0.319336           5.101094               0.022669
# 99                0.319635           5.101097               0.022709
# 100               0.319934           5.101089               0.022750
#
#      G.postprandial_sigma  G.exocytosis_mu  G.exocytosis_sigma2  ...  \
# 0                0.142542         2.550551             0.005280  ...
# 1                0.142545         2.550551             0.005280  ...
# 2                0.142552         2.550551             0.005280  ...
# 3                0.142560         2.550551             0.005281  ...
# 4                0.142570         2.550551             0.005282  ...
# ..                    ...              ...                  ...  ...
# 96               0.150296         2.550566             0.005847  ...
# 97               0.150427         2.550567             0.005857  ...
# 98               0.150561         2.550567             0.005867  ...
# 99               0.150695         2.550568             0.005878  ...
# 100              0.150831         2.550568             0.005888  ...
#
#      Spa.pancreas_sigma  Sis.pancreas_mu  Sis.pancreas_sigma2  \
# 0              4.744445         0.000010         2.198209e-12
# 1              4.429796         0.000009         1.916311e-12
# 2              4.734032         0.000010         2.188571e-12
# 3              5.169339         0.000012         2.609564e-12
# 4              4.974715         0.000011         2.416765e-12
# ..                  ...              ...                  ...
# 96             4.452888         0.000009         1.936342e-12
# 97             4.524967         0.000009         1.999536e-12
# 98             4.910371         0.000011         2.354652e-12
# 99             5.334571         0.000012         2.779053e-12
# 100            4.816285         0.000010         2.265284e-12
#
#      Sis.pancreas_sigma  Scell.pancreas_mu  Scell.pancreas_sigma2  \
# 0              0.000001       8.761947e-09           1.684010e-18
# 1              0.000001       7.643183e-09           1.469035e-18
# 2              0.000001       8.723272e-09           1.676661e-18
# 3              0.000002       1.039328e-08           1.997710e-18
# 4              0.000002       9.627870e-09           1.850682e-18
# ..                  ...                ...                    ...
# 96             0.000001       7.630526e-09           1.484470e-18
# 97             0.000001       7.876442e-09           1.532670e-18
# 98             0.000002       9.269201e-09           1.803509e-18
# 99             0.000002       1.093022e-08           2.127196e-18
# 100            0.000002       8.916063e-09           1.735354e-18
#
#      Scell.pancreas_sigma  S.exocytosis_mu  S.exocytosis_sigma2  \
# 0            1.297694e-09     9.319664e-09         3.472950e-23
# 1            1.212038e-09     9.319664e-09         1.387628e-22
# 2            1.294859e-09     9.319664e-09         3.116363e-22
# 3            1.413404e-09     9.319663e-09         5.525836e-22
# 4            1.360398e-09     9.319662e-09         8.605447e-22
# ..                    ...              ...                  ...
# 96           1.218388e-09     9.319319e-09         8.496691e-20
# 97           1.238010e-09     9.319317e-09         8.562693e-20
# 98           1.342948e-09     9.319314e-09         8.628294e-20
# 99           1.458491e-09     9.319312e-09         8.693508e-20
# 100          1.317328e-09     9.319310e-09         8.758347e-20
#
#      S.exocytosis_sigma
# 0          5.893174e-12
# 1          1.177976e-11
# 2          1.765322e-11
# 3          2.350710e-11
# 4          2.933504e-11
# ..                  ...
# 96         2.914908e-10
# 97         2.926208e-10
# 98         2.937396e-10
# 99         2.948476e-10
# 100        2.959450e-10
#
# [101 rows x 26 columns]

# %%
df_scan_mean=pd.read_csv('metamodel_scan_input_kt_mean_output_Gb_with_kt_mean_as_evidence.csv''')
display(df_scan_mean)
slope, intercept, r_value, p_value, std_err = \
  scipy.stats.linregress(df_scan_mean['INPUT_kt_mu'], df_scan_mean['Gb.postprandial_mu'])
print(slope, intercept)
# Out:
#      INPUT_kt_mu  INPUT_kt_cov  Gb.postprandial_mu  Gb.postprandial_sigma2  \
# 0            0.0          2.55            2.543239                0.094483
# 1            0.2          2.55            2.593792                0.094483
# 2            0.4          2.55            2.644345                0.094483
# 3            0.6          2.55            2.694897                0.094483
# 4            0.8          2.55            2.745450                0.094483
# ..           ...           ...                 ...                     ...
# 96          19.2          2.55            7.396311                0.094483
# 97          19.4          2.55            7.446864                0.094483
# 98          19.6          2.55            7.497417                0.094483
# 99          19.8          2.55            7.547970                0.094483
# 100         20.0          2.55            7.598523                0.094483
#
#      Gb.postprandial_sigma  G.postprandial_mu  G.postprandial_sigma2  \
# 0                 0.307381           2.831581               0.021056
# 1                 0.307381           2.876972               0.021056
# 2                 0.307381           2.922363               0.021056
# 3                 0.307381           2.967754               0.021056
# 4                 0.307381           3.013145               0.021056
# ..                     ...                ...                    ...
# 96                0.307381           7.189127               0.021056
# 97                0.307381           7.234518               0.021056
# 98                0.307381           7.279909               0.021056
# 99                0.307381           7.325300               0.021056
# 100               0.307381           7.370691               0.021056
#
#      G.postprandial_sigma  G.exocytosis_mu  G.exocytosis_sigma2  ...  \
# 0                0.145107         1.415784             0.005464  ...
# 1                0.145107         1.438479             0.005464  ...
# 2                0.145107         1.461175             0.005464  ...
# 3                0.145107         1.483870             0.005464  ...
# 4                0.145107         1.506566             0.005464  ...
# ..                    ...              ...                  ...  ...
# 96               0.145107         3.594542             0.005464  ...
# 97               0.145107         3.617237             0.005464  ...
# 98               0.145107         3.639933             0.005464  ...
# 99               0.145107         3.662628             0.005464  ...
# 100              0.145107         3.685324             0.005464  ...
#
#      Spa.pancreas_sigma  Sis.pancreas_mu  Sis.pancreas_sigma2  \
# 0              4.175905    -8.370170e-07         1.702943e-12
# 1              4.175905    -6.665397e-07         1.702943e-12
# 2              4.175905    -4.960623e-07         1.702943e-12
# 3              4.175905    -3.255850e-07         1.702943e-12
# 4              4.175905    -1.551077e-07         1.702943e-12
# ..                  ...              ...                  ...
# 96             4.175905     1.552881e-05         1.702943e-12
# 97             4.175905     1.569929e-05         1.702943e-12
# 98             4.175905     1.586976e-05         1.702943e-12
# 99             4.175905     1.604024e-05         1.702943e-12
# 100            4.175905     1.621072e-05         1.702943e-12
#
#      Sis.pancreas_sigma  Scell.pancreas_mu  Scell.pancreas_sigma2  \
# 0              0.000001      -7.352717e-10           1.306397e-18
# 1              0.000001      -5.855167e-10           1.306397e-18
# 2              0.000001      -4.357617e-10           1.306397e-18
# 3              0.000001      -2.860068e-10           1.306397e-18
# 4              0.000001      -1.362518e-10           1.306397e-18
# ..                  ...                ...                    ...
# 96             0.000001       1.364120e-08           1.306397e-18
# 97             0.000001       1.379096e-08           1.306397e-18
# 98             0.000001       1.394071e-08           1.306397e-18
# 99             0.000001       1.409047e-08           1.306397e-18
# 100            0.000001       1.424022e-08           1.306397e-18
#
#      Scell.pancreas_sigma  S.exocytosis_mu  S.exocytosis_sigma2  \
# 0            1.142977e-09    -9.323894e-09         4.717498e-20
# 1            1.142977e-09    -8.951027e-09         4.717498e-20
# 2            1.142977e-09    -8.578159e-09         4.717498e-20
# 3            1.142977e-09    -8.205291e-09         4.717498e-20
# 4            1.142977e-09    -7.832423e-09         4.717498e-20
# ..                    ...              ...                  ...
# 96           1.142977e-09     2.647141e-08         4.717498e-20
# 97           1.142977e-09     2.684428e-08         4.717498e-20
# 98           1.142977e-09     2.721715e-08         4.717498e-20
# 99           1.142977e-09     2.759002e-08         4.717498e-20
# 100          1.142977e-09     2.796289e-08         4.717498e-20
#
#      S.exocytosis_sigma
# 0          2.171980e-10
# 1          2.171980e-10
# 2          2.171980e-10
# 3          2.171980e-10
# 4          2.171980e-10
# ..                  ...
# 96         2.171980e-10
# 97         2.171980e-10
# 98         2.171980e-10
# 99         2.171980e-10
# 100        2.171980e-10
#
# [101 rows x 26 columns]
# 0.25276418607735884 2.5432389577675725

# %%
fig, ax= plt.subplots(1,2, figsize=(12.5,5))
ax[0].plot(df_scan_mean['INPUT_kt_mu']-10.0, df_scan_mean['Gb.postprandial_mu']-5.1, 'k.',
           color='#303030', markersize=7)
ax[0].set_xlabel(r'input $\overline{err}(k_t^{VE})$ [m/s]')
ax[0].set_ylabel(r'output $\overline{err}(G_b^{PR})$ [mM]')
ax[0].xaxis.set_major_formatter(matplotlib.ticker.FormatStrFormatter('%.1f'))
ax[0].yaxis.set_major_formatter(matplotlib.ticker.FormatStrFormatter('%.1f'))
ax[1].plot(np.sqrt(df_scan_cov['INPUT_kt_cov']), df_scan_cov['Gb.postprandial_sigma'], '.',
           color='#303030', markersize=7)
ax[1].set_xlabel(r'input $\sigma(k_t^{VE})$ [m/s]')
ax[1].set_ylabel(r'output $\sigma(G_b^{PR})$ [mM]')
ax[1].xaxis.set_major_formatter(matplotlib.ticker.FormatStrFormatter('%.1f'))
ax[1].yaxis.set_major_formatter(matplotlib.ticker.FormatStrFormatter('%.3f'))

ax[0].annotate("A", xy=(-0.1, 1.1), xycoords="axes fraction", fontsize=25)
ax[1].annotate("B", xy=(-0.1, 1.1), xycoords="axes fraction", fontsize=25)
fig.subplots_adjust(wspace=0.4)
plt.show()
